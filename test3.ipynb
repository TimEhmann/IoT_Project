# %%
import pandas as pd


df = pd.read_parquet('/Users/timehmann/Library/Mobile Documents/com~apple~CloudDocs/Studium/Data_Science_Karlsruhe/Data_Science_Semester6/Internet_Of_Things/IoT_Project/data/transformer_multivariate_hour_dataframe_v1.parquet')
df
# Out:
#           date_time_rounded        tmp        hum      CO2         VOC  \
# 0       2022-10-10 14:00:00  23.070000  52.903750  945.625  451.125000
# 1       2022-10-10 15:00:00  24.310909  47.668182  754.000  485.090909
# 2       2022-10-10 16:00:00  25.297500  43.447500  581.500  538.000000
# 3       2022-10-10 17:00:00  25.455000  44.930000  589.500  585.833333
# 4       2022-10-10 18:00:00  25.527500  46.942500  586.000  619.000000
# ...                     ...        ...        ...      ...         ...
# 100253  2023-09-26 20:00:00  27.545000  37.025000  518.500  954.750000
# 100254  2023-09-26 21:00:00  27.482500  37.250000  521.000  951.750000
# 100255  2023-09-26 22:00:00  27.435000  37.430000  523.750  956.750000
# 100256  2023-09-26 23:00:00  27.362500  37.570000  526.250  953.750000
# 100257  2023-09-27 00:00:00  27.335000  37.650000  525.000  947.500000
#
#                vis         IR      WIFI        BLE       rssi  ...  \
# ...
