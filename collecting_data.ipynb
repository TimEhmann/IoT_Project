# %%
import pandas as pd
import os

# %%
data = pd.concat([pd.read_csv('hka-aqm-am/' + f, skiprows=1, sep=';', engine='python') for f in os.listdir('hka-aqm-am/')])
data.head()
# Out:
#              date_time       device_id    tmp    hum   CO2  VOC  vis  IR  \
# 0  2022-09-05 12:57:18   hka-aqm-am001  25.05  51.89   991  611  106  16
# 1  2022-09-05 12:58:00   hka-aqm-am001  25.05  51.89   995  602   30   7
# 2  2022-09-05 13:20:12   hka-aqm-am001  25.05  52.08  1000  544  109  20
# 3  2022-09-05 13:35:18   hka-aqm-am001  25.17  51.79   728  450  109  17
# 4  2022-09-05 13:50:25   hka-aqm-am001  25.30  51.98   670  465   95  14
#
#    WIFI  BLE  rssi  channel_rssi   snr        gateway  channel_index  \
# 0     0    0  -127          -127 -18.2   drag-lps8-02              1
# 1     2    1  -128          -128 -15.5   drag-lps8-02              4
# 2     2    0  -133          -133 -13.8   drag-lps8-01              2
# 3     2    0  -124          -124  -6.8   drag-lps8-02              5
# 4     2    0  -132          -132 -15.2   drag-lps8-02              0
#
#    spreading_factor  bandwidth  f_cnt
# 0                10     125000      2
# ...

# %%
test = data.map(lambda x: x.strip() if isinstance(x, str) else x)

# %%
test.snr = test.snr.astype('float64')

# %%
test.to_parquet('hka_aqm_am.parquet')

# %%
data = pd.read_parquet('hka_aqm_am.parquet')
