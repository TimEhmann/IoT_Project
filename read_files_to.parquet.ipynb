# %%
import pandas as pd
import os

# %%
df = pd.concat([pd.read_csv('hka-aqm-f/' + f.removeprefix('._'), skiprows=1, sep=';', engine='python') for f in os.listdir('hka-aqm-f/')])

# %%
test = df.map(lambda x: x.strip() if isinstance(x, str) else x)

# %%
test
# Out:
#               date_time     device_id    tmp    hum  CO2  VOC  vis  IR  WIFI  \
# 0   2022-08-17 14:25:23  hka-aqm-f001  22.59  64.30  562  450   54   8     1
# 1   2022-08-17 14:26:04  hka-aqm-f001  22.90  64.78  553  450   55   7     1
# 2   2022-08-17 14:41:11  hka-aqm-f001  23.81  61.18  448  451   77  11     0
# 3   2022-08-17 14:56:17  hka-aqm-f001  24.42  59.92  440  460   83  15     0
# 4   2022-08-17 15:11:24  hka-aqm-f001  24.78  56.82  433  466   78  11     3
# ..                  ...           ...    ...    ...  ...  ...  ...  ..   ...
# 45  2023-07-17 11:29:51  hka-aqm-fu12  22.91  48.39  416  588   11   2     1
# 46  2023-07-17 11:44:57  hka-aqm-fu12  22.90  46.97  417  616   12   3     3
# 47  2023-07-17 12:00:03  hka-aqm-fu12  23.04  45.72  409  627   84  10     0
# 48  2023-07-17 12:15:09  hka-aqm-fu12  23.02  46.33  425  647   84  11     0
# 49  2023-07-17 12:30:15  hka-aqm-fu12  23.08  45.56  418  653   85  11     3
#
# ...

# %%
test.snr = test.snr.astype('float64')

# %%
test.to_parquet('data/hka-aqm-f-combined-RAW.parquet')
